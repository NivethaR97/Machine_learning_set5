# %%
#1.
import pandas as pd

df = pd.DataFrame({'a': [1, 2, None, 4]})
df['a']=pd.to_numeric(errors='coerce')
print(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 5
#       2 import pandas as pd
#       4 df = pd.DataFrame({'a': [1, 2, None, 4]})
# ----> 5 df['a']=pd.to_numeric(errors='coerce')
#       6 print(df)
#
# TypeError: to_numeric() missing 1 required positional argument: 'arg'

# %%
#2.
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 5, 6])
plt.show()

# %%
#3.
from sklearn.naive_bayes import GaussianNB

X = [[1, 2], [3, 4]]
y = [0, 1]

model = GaussianNB()
model.fit(X, y)
print(model.predict([[2, 1]]))
# Out:
# [0]

# %%
#4.
import seaborn as sns

tips = sns.load_dataset("tips")
sns.barplot(x="day", y="tip", data=tips)
plt.show()

# %%
#5.
from sklearn.metrics import confusion_matrix

y_true = [0, 1, 2, 2]
y_pred = [0, 0, 2, 2]

print(confusion_matrix(y_true, y_pred))
# Out:
# [[1 0 0]
#  [1 0 0]
#  [0 0 2]]

# %%
#6.
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(['cat', 'dog', 'mouse'])
print(le.fit_transform(['elephant']))
# Out:
# [0]

# %%
#7.
from sklearn.impute import SimpleImputer
import numpy as np

X = np.array([[1, 2], [np.nan, 3], [7, 6]])

imp = SimpleImputer(strategy='mean')
imp.fit_transform(X)
print(imp.transform([[np.nan, 3]]))
# Out:
# [[4. 3.]]

# %%
#8.
#import pandas as pd

#df = pd.read_csv('missing.csv')  #No such csv file
#print(df.head())

# %%
#9.
import numpy as np

a = np.array([1, 2, 3])
b = np.array([[1], [2], [3]])

print(np.dot(a, b))
# Out:
# [14]

# %%
#10.
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit([[1], [2], [3]], [1, 2,1])
# Out:
# LinearRegression()
